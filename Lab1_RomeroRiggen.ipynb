# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <center><font color=#555555><font size=6> MAF1731 - Microstructure and Trading Systems </font> <br> <br>
#
# <center><font color=#555555><font size=5> Financial Engineering </font> <br> <br> <br> <br>
#
# <center><font color=#555555><font size=6> I.F. SANTIAGO ROMERO RIGGEN </font> <br> <br>
#
# <center> <font color= #555555> <font size = 4> Sep 2022 </a> | <font color= #555555> <font size = 4> Repository: <a href='https://github.com/SantiRiggen/Laboratorio-1'>Link</a></font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <center> <font color= black> <font size = 6> Laboratorio 1 </font> <br> <br> <font color= blue> <font size = 5>   </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> Indice  </font>
# # <font color= blue> <font size = 3> - [Introduccion](#id1)  </font>
# # <font color= blue> <font size = 3> - [Estrategia Pasiva](#id2)  </font>
# # <font color= blue> <font size = 3> - [Resultados](#id3)  </font>

# %% [markdown]
# <div id='id1' />

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> Introduction  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# En este _notebook_ se expondrán los resultados que tuvo el portafolio con la mayoría de activos que generalmente contiene el NAFTRAC durante un periodo aproximado de dos años y medio.
# En los resultados de este laboratorio se podrá observar el comportamiento de variables respecto al portafolio tales como el propio capital, el rendimiento que se obtuvo durante cada uno de los meses, así como el rendimiento acumulado durante todo el periodo de tiempo tomado en cuenta.

# %% [markdown]
# <div id='id2' />

# %% [markdown]
# # <font color= #6B6B6B> ESTRATEGIA PASIVA </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %%
# ESTRTEGIA PASIVA
import functions
functions.pasiva()
# Out:
#                  capital      rend  rend_acum
# Date
# 2020-02-01  9.678945e+05       NaN        NaN
# 2020-03-01  8.060487e+05 -0.167214  -0.167214
# 2020-04-01  8.558800e+05  0.061822  -0.115730
# 2020-05-01  8.514481e+05 -0.005178  -0.120309
# 2020-06-01  8.930053e+05  0.048808  -0.077373
# 2020-07-01  8.811788e+05 -0.013244  -0.089592
# 2020-08-01  8.795166e+05 -0.001886  -0.091309
# 2020-09-01  8.972315e+05  0.020142  -0.073007
# 2020-10-01  8.892702e+05 -0.008873  -0.081232
# 2020-11-01  1.006635e+06  0.131979   0.040025
# 2020-12-01  1.069503e+06  0.062454   0.104979
# 2021-01-01  1.044297e+06 -0.023568   0.078937
# 2021-02-01  1.088044e+06  0.041891   0.124135
# 2021-03-01  1.154076e+06  0.060689   0.192357
# 2021-04-01  1.175607e+06  0.018656   0.214602
# 2021-05-01  1.252300e+06  0.065237   0.293839
# 2021-06-01  1.245630e+06 -0.005326   0.286948
# 2021-07-01  1.256973e+06  0.009106   0.298667
# 2021-08-01  1.317300e+06  0.047994   0.360996
# ...

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr> <div id='id3' />

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> Resultados </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 4> Estrategia pasiva </font>
# Para la estrategia pasiva podemos ver cómo se comportó el portafolio durante los casi dos años y medio. De inicio se empieza con una pérdida de valor en el portafolio durante los primeros 9 meses aproximadamente hasta que se empieza a estabilizar a finales de 2020 donde se empieza a lograr un rendimiento acumulado positivo el cual fluctuaría alrededor del 30% durante los siguientes meses manteniéndose de esta forma durante el resto del tiempo definido a pesar de tener una cantidad de meses similar con resultados tanto negativos como positivos, para cerrar con un rendimiento acumulado aproximadamente de 26%

# %% [markdown]
# <br>
